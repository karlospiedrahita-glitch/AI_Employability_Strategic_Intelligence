# %%
# ============================================================
# BUSINESS STRATEGIES
# Artificial Intelligence and Employability
# Step 9
# ============================================================

# %%
import pandas as pd

# %%
strategies = pd.DataFrame({

"Strategic Finding":[

"Continuous increase in scientific production",

"Predominance of neutral scientific evidence",

"Growing interest in AI competencies",

"Expansion of AI applications in education",

"Increasing collaboration between academia and industry"

],

"Business Opportunity":[

"Invest in AI research",

"Strengthen evidence-based decision making",

"Develop AI training programs",

"Modernize educational processes",

"Promote strategic alliances"

],

"Strategic Objective":[

"Increase innovation capacity",

"Improve organizational intelligence",

"Strengthen employability",

"Improve educational quality",

"Increase technology transfer"

]

})

strategies
# Out:
#                                    Strategic Finding  \
# 0       Continuous increase in scientific production
# 1        Predominance of neutral scientific evidence
# 2                Growing interest in AI competencies
# 3          Expansion of AI applications in education
# 4  Increasing collaboration between academia and ...
#
#                         Business Opportunity  \
# 0                      Invest in AI research
# 1  Strengthen evidence-based decision making
# 2               Develop AI training programs
# 3            Modernize educational processes
# 4                Promote strategic alliances
#
#                    Strategic Objective
# 0         Increase innovation capacity
# 1  Improve organizational intelligence
# 2             Strengthen employability
# 3          Improve educational quality
# 4         Increase technology transfer

# %%
strategies.to_csv(

"Business_Strategies.csv",

index=False

)

print("Business strategies exported successfully.")
# Out:
# Business strategies exported successfully.

# %%
kpis = pd.DataFrame({

"KPI":[

"Scientific publications",

"International collaborations",

"Positive sentiment",

"AI training initiatives",

"Research impact"

],

"Formula":[

"Annual publications",

"International papers / Total papers",

"Positive papers / Total papers",

"Training programs implemented",

"Average citations per publication"

],

"Frequency":[

"Annual",

"Annual",

"Annual",

"Semester",

"Annual"

]

})

kpis
# Out:
#                             KPI                              Formula Frequency
# 0       Scientific publications                  Annual publications    Annual
# 1  International collaborations  International papers / Total papers    Annual
# 2            Positive sentiment       Positive papers / Total papers    Annual
# 3       AI training initiatives        Training programs implemented  Semester
# 4               Research impact    Average citations per publication    Annual

# %%
kpis.to_csv(

"KPI_Framework.csv",

index=False

)

print("KPI framework exported successfully.")
# Out:
# KPI framework exported successfully.
